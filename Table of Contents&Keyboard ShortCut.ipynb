# %% [markdown]
# # Table of Contents&Keyboard ShortCut

# %% [markdown]
# 1. chap1
#     - 자료형, Boolean
#     - 변수
#     - 주석처리
#     - 연산자, 간단한 수식, 숫자처리 함수, 난수
#     - 문자열(+ 슬라이싱, 처리 함수, 포맷)
#     - 탈출문자(\관련)

# %% [markdown]
# 2. chap2
# - 리스트
# - 사전
# - 튜플
# - 집합
# - 자료구조의 변경
# - IF, For, While (+ 한줄 for)
# - continue & break

# %%
# Headers1
## Headers2
### Headers3
#### Headers4
##### Headers5

# %% [markdown]
# # Headers1
# ## Headers2
# ### Headers3
# #### Headers4
# ##### Headers5

# %%
*italics*
_italics_

# %% [markdown]
# *italics*
#
# _italics_

# %%
**bold**
__bold__
# Out:
#   File "<ipython-input-2-b9557309d2af>", line 1
#     **bold**
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# **bold**
#
# __bold__

# %%
~~strike through~~

# %% [markdown]
# ~~strike through~~

# %%
1.⌴First item
2.⌴Second item
⌴1.⌴Subitem

# %% [markdown]
# 1. First item
# 2. Second item
#  1. Subitem

# %%
*⌴Item 1
⌴Indent
-⌴Item 2
⌴+⌴Item 3

# %% [markdown]
# * Item 1
#  Indent
# - Item 2
#  + Item 3

# %%
- [x] Done
- [ ] To do

# %% [markdown]
# - [x] Done
# - [ ] To do

# %%
A
Line⌴⌴
Break

# %% [markdown]
# A
# Line
# Break

# %%
---
* * *

# %% [markdown]
# ---
# * * *

# %%
> blockquote text

# %% [markdown]
# > blockquote text

# %%
|Left |Center|Right|
|:-----|:----:|----:|
|1 |A |C |
|2 |B |D |

# %% [markdown]
# |Left |Center|Right|
# |:-----|:----:|----:|
# |1 |A |C |
# |2 |B |D |

# %%
$$\sqrt{k}$$
Inline: $\sqrt{k}$

# %% [markdown]
# $$\sqrt{k}$$
# Inline: $\sqrt{k}$

# %% [markdown]
# - 가운데에 하나만 달랑 쓸거면 위처럼
# - 줄 안에서 쓸거면 아래처럼

# %% [markdown]
# - 나중에 사진 넣는법 옮겨 놓기
# - https://wonderbout.tistory.com/50 나중에 C: 사용자 거치는거 문제생기면 경로 바꾸기

# %% [markdown]
# |공용 단축키|설명|
# |:-----|----:|
# |Shift + Enter|	액티브 셀을 실행하고 아래 셀을 선택한다.|
# |Ctrl + Enter|	액티브 셀을 실행한다.|
# |Alt + Enter|	액티브 셀을 실행하고 아래에 셀을 하나 생성한다.|
#
#
# |명령 모드 단축키|	설명|
# |:----|----:|
# |↑, ↓|	셀 선택|
# |A|	액티브 코드 셀의 위(Above)에 셀을 하나 생성한다.|
# |B|	액티브 코드 셀의 위(Below)에 셀을 하나 생성한다.|
# |Ctrl + S|	Notebook 파일을 저장한다.|
# |Shift + L|	줄 번호 표시를 토글한다.|
# |D, D|	(D 두번 연속으로 타이핑)액티브 코드 셀을 삭제한다.|
# |Z|	삭제한 셀을 하나 복원한다.|
# |Y|	액티브 코드 셀을 Code 타입(코드를 기술하는 타입)으로 한다.|
# |M|	액티브 코드 셀을 Markdown 타입으로 한다.|
# |O, O|	커널을 재시작한다.|
# |P|	명령 팔레트를 연다.|
# |H|	단축키 목록을 표시한다. Enter 키로 숨긴다.|
