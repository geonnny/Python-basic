# %% [markdown]
# # 2. 출생아 수 및 합계 출산율

# %%
import pandas as pd
df = pd.read_excel('stat_142801.xls', skiprows = 2, nrows=2, index_col=0) # 0번째 col 을 idx로 가져옴
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018     2019    2020
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800  302.700  272.30
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977    0.918    0.84

# %%
#df.loc['출생아 수']
df.index
# Out:
# Index(['출생아 수', '합계 출산율'], dtype='object')

# %%
df.index.values   # 이것 때문에 앞에서 안됐음. \xa0
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index = {'출생아\xa0수' : '출생아 수', '합계\xa0출산율' : '합계 출산율'}, inplace=True)
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc['출생아 수']
# Out:
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# Name: 출생아 수, dtype: float64

# %%
df.iloc[0] # 이게 더 편함
# Out:
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# Name: 출생아 수, dtype: float64

# %%
# 데이터 프레임 트랜스포즈
df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.840

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15 
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.plot(df.index, df['출생아 수'])
plt.plot(df.index, df['합계 출산율'])

# %%
# x축 공유하는 그래프 그리기
fig, ax1 = plt.subplots(figsize = (10,7))    # sibplots() = 1x1 그래프
ax1.plot(df.index, df['출생아 수'], c = '#ff812d')

ax2 = ax1.twinx()    # x축을 공유하는 쌍둥이 axis
ax2.plot(df.index, df['합계 출산율'], c = '#ffd100')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize = (13,5))    # sibplots() = 1x1 그래프
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = '#ff812d')
# plot 에는 color 대신 c 라고만 해도 되는데 bar는 안됨 ..


ax2 = ax1.twinx()    # x축을 공유하는 쌍둥이 axis
ax2.set_ylabel('합계 출산율 (가입여성 1명당 명)')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], c = '#ffd100')

# %%
# 바 위에 숫자 넣기
fig, ax1 = plt.subplots(figsize = (13,5))    # sibplots() = 1x1 그래프
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = '#ff812d')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val +12, val, ha='center')  # (x좌표,y좌표, 값)

ax2 = ax1.twinx()    # x축을 공유하는 쌍둥이 axis
ax2.set_ylabel('합계 출산율 (가입여성 1명당 명)')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], c = '#ffd100')

# %%
# 꺾은 선 스타일 변경
fig, ax1 = plt.subplots(figsize = (13,5))    # sibplots() = 1x1 그래프
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = '#ff812d')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val +12, val, ha='center')  # (x좌표,y좌표, 값)

ax2 = ax1.twinx()    # x축을 공유하는 쌍둥이 axis
ax2.set_ylabel('합계 출산율 (가입여성 1명당 명)')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], c = '#ffd100', marker = 'o', ms = 15, lw=5,
        mec = 'w', mew = 3)  # mec: markeredgecolor, mew = markeredgewidth

# %%
# 꺽은선 위에 숫자 쓰기
fig, ax1 = plt.subplots(figsize = (13,5))    # sibplots() = 1x1 그래프
fig.suptitle('출생아 수 및 합계 출산율')
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,700)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = '#ff812d')
ax1.grid(axis = 'y')
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val +12, val, ha='center')  # (x좌표,y좌표, 값)

ax2 = ax1.twinx()    # x축을 공유하는 쌍둥이 axis
ax2.set_ylabel('합계 출산율 (가입여성 1명당 명)')
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.plot(df.index, df['합계 출산율'], c = '#ffd100', marker = 'o', ms = 15, lw=5,
        mec = 'w', mew = 3)  # mec: markeredgecolor, mew = markeredgewidth
for idx, val in enumerate(df['합계 출산율']):
    ax2.text(idx, val + 0.08 , val, ha='center')
